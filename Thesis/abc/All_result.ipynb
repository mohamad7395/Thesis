# %%
import pandas as pd

data = [
    # T5-Base
    {"Model": "T5-Base", "Data_Source": "Original", "Variation": "Original", "Laptop14_F1": 93.32, "Rest14_F1": 95.12, "Rest15_F1": 80.90, "Rest16_F1": 83.28},

    {"Model": "T5-Base", "Data_Source": "Agentic", "Variation": "Gen. x1", "Laptop14_F1": 46.18, "Rest14_F1": 66.53, "Rest15_F1": 50.82, "Rest16_F1": 54.73},
    {"Model": "T5-Base", "Data_Source": "Agentic", "Variation": "Gen. x2", "Laptop14_F1": 46.83, "Rest14_F1": 65.09, "Rest15_F1": 50.19, "Rest16_F1": 54.30},

    {"Model": "T5-Base", "Data_Source": "Prompting", "Variation": "Gen. x1", "Laptop14_F1": 41.46, "Rest14_F1": 58.85, "Rest15_F1": 48.45, "Rest16_F1": 51.13},
    {"Model": "T5-Base", "Data_Source": "Prompting", "Variation": "Gen. x2", "Laptop14_F1": 40.35, "Rest14_F1": 55.73, "Rest15_F1": 46.49, "Rest16_F1": 49.05},

    {"Model": "T5-Base", "Data_Source": "Agentic", "Variation": "Mixed x1", "Laptop14_F1": 93.82, "Rest14_F1": 94.63, "Rest15_F1": 80.98, "Rest16_F1": 85.21},
    {"Model": "T5-Base", "Data_Source": "Agentic", "Variation": "Mixed x2", "Laptop14_F1": 93.50, "Rest14_F1": 94.26, "Rest15_F1": 82.22, "Rest16_F1": 84.37},

    {"Model": "T5-Base", "Data_Source": "Prompting", "Variation": "Mixed x1", "Laptop14_F1": 92.83, "Rest14_F1": 94.53, "Rest15_F1": 80.43, "Rest16_F1": 83.83},
    {"Model": "T5-Base", "Data_Source": "Prompting", "Variation": "Mixed x2", "Laptop14_F1": 92.97, "Rest14_F1": 94.14, "Rest15_F1": 78.88, "Rest16_F1": 84.72},

    # Tk-Instruct
    {"Model": "Tk-Instruct", "Data_Source": "Original", "Variation": "Original", "Laptop14_F1": 93.91, "Rest14_F1": 95.01, "Rest15_F1": 83.41, "Rest16_F1": 85.47},

    {"Model": "Tk-Instruct", "Data_Source": "Agentic", "Variation": "Gen. x1", "Laptop14_F1": 47.23, "Rest14_F1": 65.23, "Rest15_F1": 50.63, "Rest16_F1": 55.69},
    {"Model": "Tk-Instruct", "Data_Source": "Agentic", "Variation": "Gen. x2", "Laptop14_F1": 45.39, "Rest14_F1": 64.00, "Rest15_F1": 50.82, "Rest16_F1": 52.02},

    {"Model": "Tk-Instruct", "Data_Source": "Prompting", "Variation": "Gen. x1", "Laptop14_F1": 39.69, "Rest14_F1": 55.38, "Rest15_F1": 44.67, "Rest16_F1": 45.86},
    {"Model": "Tk-Instruct", "Data_Source": "Prompting", "Variation": "Gen. x2", "Laptop14_F1": 39.26, "Rest14_F1": 51.71, "Rest15_F1": 43.89, "Rest16_F1": 43.83},

    {"Model": "Tk-Instruct", "Data_Source": "Agentic", "Variation": "Mixed x1", "Laptop14_F1": 93.93, "Rest14_F1": 94.20, "Rest15_F1": 84.12, "Rest16_F1": 87.14},
    {"Model": "Tk-Instruct", "Data_Source": "Agentic", "Variation": "Mixed x2", "Laptop14_F1": 94.07, "Rest14_F1": 93.34, "Rest15_F1": 82.50, "Rest16_F1": 86.38},

    {"Model": "Tk-Instruct", "Data_Source": "Prompting", "Variation": "Mixed x1", "Laptop14_F1": 93.80, "Rest14_F1": 94.10, "Rest15_F1": 82.30, "Rest16_F1": 85.32},
    {"Model": "Tk-Instruct", "Data_Source": "Prompting", "Variation": "Mixed x2", "Laptop14_F1": 93.35, "Rest14_F1": 94.20, "Rest15_F1": 80.00, "Rest16_F1": 84.39},
]

df = pd.DataFrame(data)

# %%
df.to_csv('ATE_all_results.csv')

# %%
data = [
    # T5-Base
    {"Model": "T5-Base", "Data_Source": "Original", "Variation": "Original", "Laptop14_F1": 79.78, "Rest14_F1": 86.25, "Rest15_F1": 88.74, "Rest16_F1": 91.86},

    {"Model": "T5-Base", "Data_Source": "Agentic", "Variation": "Gen. x1", "Laptop14_F1": 77.42, "Rest14_F1": 79.64, "Rest15_F1": 81.54, "Rest16_F1": 88.29},
    {"Model": "T5-Base", "Data_Source": "Agentic", "Variation": "Gen. x2", "Laptop14_F1": 78.05, "Rest14_F1": 80.00, "Rest15_F1": 81.73, "Rest16_F1": 89.26},

    {"Model": "T5-Base", "Data_Source": "Prompting", "Variation": "Gen. x1", "Laptop14_F1": 75.86, "Rest14_F1": 76.85, "Rest15_F1": 81.84, "Rest16_F1": 87.57},
    {"Model": "T5-Base", "Data_Source": "Prompting", "Variation": "Gen. x2", "Laptop14_F1": 74.92, "Rest14_F1": 75.53, "Rest15_F1": 80.44, "Rest16_F1": 86.66},

    {"Model": "T5-Base", "Data_Source": "Agentic", "Variation": "Mixed x1", "Laptop14_F1": 83.38, "Rest14_F1": 86.78, "Rest15_F1": 88.92, "Rest16_F1": 93.33},
    {"Model": "T5-Base", "Data_Source": "Agentic", "Variation": "Mixed x2", "Laptop14_F1": 81.34, "Rest14_F1": 86.42, "Rest15_F1": 88.56, "Rest16_F1": 93.17},

    {"Model": "T5-Base", "Data_Source": "Prompting", "Variation": "Mixed x1", "Laptop14_F1": 79.93, "Rest14_F1": 86.96, "Rest15_F1": 88.37, "Rest16_F1": 93.82},
    {"Model": "T5-Base", "Data_Source": "Prompting", "Variation": "Mixed x2", "Laptop14_F1": 81.34, "Rest14_F1": 85.62, "Rest15_F1": 88.37, "Rest16_F1": 93.00},

    # Tk-Instruct
    {"Model": "Tk-Instruct", "Data_Source": "Original", "Variation": "Original", "Laptop14_F1": 82.75, "Rest14_F1": 87.41, "Rest15_F1": 88.56, "Rest16_F1": 94.30},

    {"Model": "Tk-Instruct", "Data_Source": "Agentic", "Variation": "Gen. x1", "Laptop14_F1": 74.60, "Rest14_F1": 79.37, "Rest15_F1": 80.44, "Rest16_F1": 88.78},
    {"Model": "Tk-Instruct", "Data_Source": "Agentic", "Variation": "Gen. x2", "Laptop14_F1": 76.64, "Rest14_F1": 79.10, "Rest15_F1": 79.88, "Rest16_F1": 89.26},

    {"Model": "Tk-Instruct", "Data_Source": "Prompting", "Variation": "Gen. x1", "Laptop14_F1": 73.04, "Rest14_F1": 76.25, "Rest15_F1": 82.28, "Rest16_F1": 86.17},
    {"Model": "Tk-Instruct", "Data_Source": "Prompting", "Variation": "Gen. x2", "Laptop14_F1": 72.57, "Rest14_F1": 76.25, "Rest15_F1": 79.70, "Rest16_F1": 85.04},

    {"Model": "Tk-Instruct", "Data_Source": "Agentic", "Variation": "Mixed x1", "Laptop14_F1": 80.72, "Rest14_F1": 88.30, "Rest15_F1": 88.92, "Rest16_F1": 93.33},
    {"Model": "Tk-Instruct", "Data_Source": "Agentic", "Variation": "Mixed x2", "Laptop14_F1": 81.34, "Rest14_F1": 87.41, "Rest15_F1": 88.74, "Rest16_F1": 92.68},

    {"Model": "Tk-Instruct", "Data_Source": "Prompting", "Variation": "Mixed x1", "Laptop14_F1": 80.87, "Rest14_F1": 87.58, "Rest15_F1": 88.00, "Rest16_F1": 92.52},
    {"Model": "Tk-Instruct", "Data_Source": "Prompting", "Variation": "Mixed x2", "Laptop14_F1": 81.19, "Rest14_F1": 87.23, "Rest15_F1": 87.60, "Rest16_F1": 92.84},
]

df2 = pd.DataFrame(data)

# %%
df2.to_csv('ATSC_all_results.csv')

# %%
data = [
    # T5-Base
    {"Model": "T5-Base", "Data_Source": "Original", "Variation": "Original", "Laptop14_F1": 81.19, "Rest14_F1": 81.34, "Rest15_F1": 73.38, "Rest16_F1": 79.47},

    {"Model": "T5-Base", "Data_Source": "Agentic", "Variation": "Gen. x1", "Laptop14_F1": 28.42, "Rest14_F1": 48.79, "Rest15_F1": 37.94, "Rest16_F1": 41.49},
    {"Model": "T5-Base", "Data_Source": "Agentic", "Variation": "Gen. x2", "Laptop14_F1": 28.81, "Rest14_F1": 48.88, "Rest15_F1": 37.58, "Rest16_F1": 42.56},

    {"Model": "T5-Base", "Data_Source": "Prompting", "Variation": "Gen. x1", "Laptop14_F1": 23.13, "Rest14_F1": 38.15, "Rest15_F1": 28.58, "Rest16_F1": 35.30},
    {"Model": "T5-Base", "Data_Source": "Prompting", "Variation": "Gen. x2", "Laptop14_F1": 22.80, "Rest14_F1": 36.00, "Rest15_F1": 29.09, "Rest16_F1": 34.51},

    {"Model": "T5-Base", "Data_Source": "Agentic", "Variation": "Mixed x1", "Laptop14_F1": 82.37, "Rest14_F1": 80.31, "Rest15_F1": 76.00, "Rest16_F1": 79.72},
    {"Model": "T5-Base", "Data_Source": "Agentic", "Variation": "Mixed x2", "Laptop14_F1": 78.84, "Rest14_F1": 81.52, "Rest15_F1": 73.89, "Rest16_F1": 78.79},

    {"Model": "T5-Base", "Data_Source": "Prompting", "Variation": "Mixed x1", "Laptop14_F1": 80.68, "Rest14_F1": 80.42, "Rest15_F1": 72.92, "Rest16_F1": 79.02},
    {"Model": "T5-Base", "Data_Source": "Prompting", "Variation": "Mixed x2", "Laptop14_F1": 78.71, "Rest14_F1": 80.42, "Rest15_F1": 72.34, "Rest16_F1": 76.06},

    # Tk-Instruct
    {"Model": "Tk-Instruct", "Data_Source": "Original", "Variation": "Original", "Laptop14_F1": 82.03, "Rest14_F1": 82.49, "Rest15_F1": 77.25, "Rest16_F1": 81.60},

    {"Model": "Tk-Instruct", "Data_Source": "Agentic", "Variation": "Gen. x1", "Laptop14_F1": 31.98, "Rest14_F1": 50.07, "Rest15_F1": 40.02, "Rest16_F1": 46.63},
    {"Model": "Tk-Instruct", "Data_Source": "Agentic", "Variation": "Gen. x2", "Laptop14_F1": 31.72, "Rest14_F1": 50.60, "Rest15_F1": 41.04, "Rest16_F1": 46.83},

    {"Model": "Tk-Instruct", "Data_Source": "Prompting", "Variation": "Gen. x1", "Laptop14_F1": 23.47, "Rest14_F1": 39.47, "Rest15_F1": 31.87, "Rest16_F1": 33.12},
    {"Model": "Tk-Instruct", "Data_Source": "Prompting", "Variation": "Gen. x2", "Laptop14_F1": 22.04, "Rest14_F1": 36.03, "Rest15_F1": 31.32, "Rest16_F1": 33.12},

    {"Model": "Tk-Instruct", "Data_Source": "Agentic", "Variation": "Mixed x1", "Laptop14_F1": 81.29, "Rest14_F1": 82.38, "Rest15_F1": 76.79, "Rest16_F1": 80.80},
    {"Model": "Tk-Instruct", "Data_Source": "Agentic", "Variation": "Mixed x2", "Laptop14_F1": 80.62, "Rest14_F1": 81.66, "Rest15_F1": 75.60, "Rest16_F1": 82.21},

    {"Model": "Tk-Instruct", "Data_Source": "Prompting", "Variation": "Mixed x1", "Laptop14_F1": 80.46, "Rest14_F1": 81.22, "Rest15_F1": 74.41, "Rest16_F1": 77.54},
    {"Model": "Tk-Instruct", "Data_Source": "Prompting", "Variation": "Mixed x2", "Laptop14_F1": 79.70, "Rest14_F1": 81.52, "Rest15_F1": 74.10, "Rest16_F1": 81.30},
]

df3 = pd.DataFrame(data)

# %%
df3.to_csv('ASPE_all_results.csv')
