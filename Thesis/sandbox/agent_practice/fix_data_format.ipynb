# %%
import pandas as pd
import ast

original_data = pd.read_csv('/home/s6moakba/InstructABSA/Dataset/Benchmarks/SemEval14/Train/Restaurants_Train.csv')
original_data.head()
# Out:
#    sentenceId                                           raw_text  \
# 0        3121               But the staff was so horrible to us.
# 1        2777  To be completely fair, the only redeeming fact...
# 2        1634  The food is uniformly exceptional, with a very...
# 3        2534  Where Gabriela personaly greets you and recomm...
# 4         583  For those that go once and don't enjoy it, all...
#
#                                          aspectTerms  \
# 0        [{'term': 'staff', 'polarity': 'negative'}]
# 1         [{'term': 'food', 'polarity': 'positive'}]
# 2  [{'term': 'food', 'polarity': 'positive'}, {'t...
# 3     [{'term': 'noaspectterm', 'polarity': 'none'}]
# 4     [{'term': 'noaspectterm', 'polarity': 'none'}]
#
#                                     aspectCategories
# 0  [{'category': 'service', 'polarity': 'negative'}]
# 1  [{'category': 'food', 'polarity': 'positive'},...
# 2     [{'category': 'food', 'polarity': 'positive'}]
# 3  [{'category': 'service', 'polarity': 'positive'}]
# 4  [{'category': 'anecdotes/miscellaneous', 'pola...

# %%
gen_data = pd.read_csv('/home/s6moakba/Thesis/Data_Generation/Prompting/data/test.csv')

# %%
gen_data
# Out:
#                                                Terms  \
# 0            cafe,Southern Indian cuisine,Pad See Ew
# 1  selection of meats and seafoods,Cantonese,menu...
#
#                      Polarity  \
# 0  negative,negative,positive
# 1  negative,negative,positive
#
#                                               prompt  \
# 0  \n                You are a critic who can gen...
# 1  \n                You are a critic who can gen...
#
#                                                 text  \
# 0  content="The cafe had poor service and the Sou...
# 1  content="The selection of meats and seafood wa...
#
#                                             sentence
# 0  The cafe had poor service and the Southern Ind...
# 1  The selection of meats and seafood was disappo...

# %%
gen_data.columns.tolist()
# Out:
# ['sentence', 'Terms', 'Polarity']

# %%
gen_data['Terms'] = gen_data['Terms'].apply(lambda x: x.split(','))
gen_data['Polarity'] = gen_data['Polarity'].apply(lambda x: x.split(','))

# %%
# def process_terms(terms):
#     terms_list = terms[1:-1].split(', ')
#     terms_list = [item[1:-1].replace("\\", "") for item in terms_list]
#     return terms_list

# %%
# gen_data['Terms'] = gen_data['Terms'].apply(process_terms)
# gen_data['Polarity'] = gen_data['Polarity'].apply(process_terms)

# %%
gen_data['sentence'] = gen_data['sentence'].apply(lambda x: x if isinstance(x, str) else '.')

# %%
gen_data
# Out:
#                                                Terms  \
# 0        [cafe, Southern Indian cuisine, Pad See Ew]
# 1  [selection of meats and seafoods, Cantonese, m...
#
#                          Polarity  \
# 0  [negative, negative, positive]
# 1  [negative, negative, positive]
#
#                                               prompt  \
# 0  \n                You are a critic who can gen...
# 1  \n                You are a critic who can gen...
#
#                                                 text  \
# 0  content="The cafe had poor service and the Sou...
# 1  content="The selection of meats and seafood wa...
#
#                                             sentence
# 0  The cafe had poor service and the Southern Ind...
# 1  The selection of meats and seafood was disappo...

# %% [markdown]
# # filter rows that do not contain Terms

# %%
# def filter_rows(row):
#     aspects = row['Terms']
#     if all(aspect in row['sentence'] for aspect in aspects):
#         row['correct'] = True    
#     else:
#         row['correct'] = False
#     return row

# gen_data = gen_data.apply(filter_rows, axis=1)

# %%
# gen_data_filtered = gen_data[gen_data['correct'] == True]
# gen_data_filtered.shape
# Out:
# (5293, 4)

# %%
# gen_data_filtered = gen_data_filtered.drop(columns=['correct'])

# %%
def create_aspect_terms(aspect,polarity):
    aspect_terms = []
    for aspect, polarity in zip(aspect, polarity):
        aspect_terms.append({'term': aspect, 'polarity': polarity})
    return aspect_terms

# %%
# gen_data_filtered['aspectTerms'] = gen_data_filtered.apply(lambda x: create_aspect_terms(x['Terms'],x['Polarity']),axis=1)

# %%
gen_data['aspectTerms'] = gen_data.apply(lambda x: create_aspect_terms(x['Terms'],x['Polarity']),axis=1)

# %%
# gen_data_filtered.rename(columns={'sentence':'raw_text'},inplace=True)

# %%
# gen_data_filtered['aspectCategories'] = gen_data_filtered['aspectTerms'].apply(lambda x: [{'category': 'general', 'polarity': 'neutral'}])

# %%
# gen_data_filtered['sentenceId'] = gen_data_filtered.index

# %%
gen_data
# Out:
#                                                Terms  \
# 0        [cafe, Southern Indian cuisine, Pad See Ew]
# 1  [selection of meats and seafoods, Cantonese, m...
#
#                          Polarity  \
# 0  [negative, negative, positive]
# 1  [negative, negative, positive]
#
#                                               prompt  \
# 0  \n                You are a critic who can gen...
# 1  \n                You are a critic who can gen...
#
#                                                 text  \
# 0  content="The cafe had poor service and the Sou...
# 1  content="The selection of meats and seafood wa...
#
#                                             sentence  \
# 0  The cafe had poor service and the Southern Ind...
# 1  The selection of meats and seafood was disappo...
#
#                                          aspectTerms
# 0  [{'term': 'cafe', 'polarity': 'negative'}, {'t...
# 1  [{'term': 'selection of meats and seafoods', '...

# %%
gen_data.rename(columns={'sentence':'raw_text'},inplace=True)
gen_data['aspectCategories'] = gen_data['aspectTerms'].apply(lambda x: [{'category': 'general', 'polarity': 'neutral'}])
gen_data.drop(columns=['text','prompt'], inplace=True)
gen_data['sentenceId'] = gen_data.index

# %%
gen_data
# Out:
#                                                Terms  \
# 0        [cafe, Southern Indian cuisine, Pad See Ew]
# 1  [selection of meats and seafoods, Cantonese, m...
#
#                          Polarity  \
# 0  [negative, negative, positive]
# 1  [negative, negative, positive]
#
#                                             raw_text  \
# 0  The cafe had poor service and the Southern Ind...
# 1  The selection of meats and seafood was disappo...
#
#                                          aspectTerms  \
# 0  [{'term': 'cafe', 'polarity': 'negative'}, {'t...
# 1  [{'term': 'selection of meats and seafoods', '...
#
#                                    aspectCategories  sentenceId
# 0  [{'category': 'general', 'polarity': 'neutral'}]           0
# 1  [{'category': 'general', 'polarity': 'neutral'}]           1

# %%
path = '/home/s6moakba/InstructABSA/Dataset/AUG/14_l/prompting_14_l_5k.csv'
gen_data.to_csv(path, index=False)
